# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas
import matplotlib.pyplot as plt
import string

import re
from string import punctuation
from collections import Counter

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# ### 2. Reading the csv file and converting into Pandas Dataframe

# %%
data = pd.read_csv('train.tsv', delimiter='\t', encoding='utf-8')
data.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
dsp = pd.DataFrame(data['item_description'])
dsp.head()
# Out:
#                                     item_description
# 0                                 No description yet
# 1  This keyboard is in great condition and works ...
# 2  Adorable top with a hint of lace and a key hol...
# 3  New with tags. Leather horses. Retail for [rm]...
# 4          Complete with certificate of authenticity

# %%
dsp = dsp.fillna('Missing')
dsp.isnull().sum()
# Out:
# item_description    0
# dtype: int64

# %%
dsp['item_condition_id'] = data['item_condition_id']

# %%
def processItemCond(cond):
    if cond > 2:
        cond = 1
    else:
        cond = 0
        
    return cond    

binary_cond = []
for cond in dsp['item_condition_id']:
    binary_cond.append(processItemCond(cond)) 
    
dsp['binary item condition'] = binary_cond
dsp.head()

# %% [markdown]
# ### 3. Cleaning up Item Description Text

# %%
# helper function to clean tweets
def processDescription(text):
    # Remove HTML special entities (e.g. &amp;)
    text = re.sub(r'\&\w*;', '', text)
    #Convert @username to AT_USER
    text = re.sub('@[^\s]+','',text)
    # Remove tickers
    text = re.sub(r'\$\w*', '', text)
    # To lowercase
    text = text.lower()
    # Remove hyperlinks
    text = re.sub(r'https?:\/\/.*\/\w*', '', text)
    # Remove hashtags
    text = re.sub(r'#\w*', '', text)
    # Remove Punctuation and split 's, 't, 've with a space for filter
    text = re.sub(r'[' + punctuation.replace('@', '') + ']+', ' ', text)
    # Remove words with 2 or fewer letters
    text = re.sub(r'\b\w{1,2}\b', '', text)
    # Remove whitespace (including new line characters)
    text = re.sub(r'\s\s+', ' ', text)
    # Remove single space remaining at the front of the tweet.
    text = text.lstrip(' ') 
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    text = ''.join(c for c in text if c <= '\uFFFF') 
    return text
# ______________________________________________________________
# clean dataframe's text column
dsp['item_description'] = dsp['item_description'].apply(processDescription)

# preview some cleaned tweets
dsp.head()
# Out:
#                                           item_description  item_condition_id
# 0                                          description yet                  3
# 1        this keyboard great condition and works like c...                  3
# 2        adorable top with hint lace and key hole the b...                  1
# 3        new with tags leather horses retail for each s...                  1
# 4                   complete with certificate authenticity                  1
# 5        banana republic bottoms candies skirt with mat...                  3
# 6        size small but straps slightly shortened fit b...                  3
# 7        you get three pairs sophie cheer shorts size s...                  3
# 8          girls size small plus green three shorts total                   3
# 9        realized his pants are backwards after the pic...                  3
# 10                               full size 1oz for sephora                  2
# 11       new pink body mists each fresh clean sun kiss ...                  1
# 12                                         great condition                  2
# 13                                         description yet                  1
# 14       authentic suede fringe boots great condition s...                  3
# 15       brand new deluxe travel size products contains...                  1
# 16          glitter eyeshadows one brass and one bleached                   1
# 17       brand new box size medium color coral retails ...                  1
# 18       this authentic pallete too faced brand new min...                  1
# 19       fancy dressy casual dress down 100 polyester w...                  2
# 20                      size worn once excellent condition                  3
# 21       nwt victoria secret ultimate sport bra maximum...                  1
# 22       reasonable offers welcomed but you ask lowest ...                  3
# 23       brand new never used all colors are available ...                  1
# 24       lanascloset description never worn ✨ delete up...                  2
# 25       they are 100 percent authentic they are beater...                  3
# 26            brand new otterbox defender iphone plus plus                  1
# 27                       worn one time excellent condition                  3
# 28       beautiful excellent condition zips and ties th...                  2
# 29       29w 33l social stretch hollister jeans please ...                  3
# ...                                                    ...                ...
# 1482505  great condition few signs wear the inside but ...                  3
# 1482506  brand new sealed box kitchen aid kitchenaid qu...                  1
# 1482507           just the game and the case lightly used                   3
# 1482508                                      new with tags                  1
# 1482509  fit bit charge comes with box charger pack scr...                  3
# 1482510  popsockets for all phone tablet add clip mount...                  1
# 1482511  brand bebe beauty lip gloss color icon brand n...                  1
# 1482512                                    nwot blue size                   2
# 1482513  ultra rare single card condition free shipping...                  3
# 1482514  leather navy and creme polka dot with brown ac...                  3
# 1482515                                        size medium                  3
# 1482516  bath body works scented candle vanilla blossom...                  1
# 1482517  see all the bras have listed key jbr114 vsbras...                  3
# 1482518                      appear vtg the pink one coro                   3
# 1482519  brand new with tags victoria secret logo thong...                  1
# 1482520  bundle baby gap first favorites months long sl...                  3
# 1482521                              brand new never used                   1
# 1482522  perfect design for tribute not fit for tribute...                  1
# 1482523        still more than half left this color orgasm                  3
# 1482524  ▪️nwot ▪️perfect condition ▪️barely been worn ...                  2
# 1482525  removable straps make strapless size perfect c...                  2
# 1482526  great harry potter shirt hogwarts school witch...                  2
# 1482527  brand new black and white ribbed mock neck bod...                  1
# 1482528  purple and paisley victoria secret tankini siz...                  2
# 1482529  for the set both perfect condition holes stain...                  2
# 1482530  lace says size small but fits medium perfectly...                  2
# 1482531     little mermaid handmade dress never worn size                   2
# 1482532                 used once twice still great shape                   2
# 1482533  there each one that you see red orange and the...                  3
# 1482534  new with tag red with sparkle firm price free ...                  1
#
# [1482535 rows x 2 columns]

# %% [markdown]
# ### 4. Counting no. of words in each tweet

# %%
# get a word count per sentence column
def count_no_of_words(sentence):
    return len(sentence.split())
    
dsp['word count'] = dsp['item_description'].apply(count_no_of_words)
dsp.head()
# Out:
#                                     item_description  item_condition_id  \
# 0                                    description yet                  3
# 1  this keyboard great condition and works like c...                  3
# 2  adorable top with hint lace and key hole the b...                  1
# 3  new with tags leather horses retail for each s...                  1
# 4             complete with certificate authenticity                  1
#
#    word count
# 0           2
# 1          29
# 2          18
# 3          27
# 4           4

# %%
# get most common words in training dataset
all_words = []
for line in list(dsp['item_description']):
    words = line.split()
    for word in words:
        all_words.append(word.lower())
    
    
Counter(all_words).most_common(10)
# Out:
# [('and', 842727),
#  ('the', 651761),
#  ('for', 547873),
#  ('new', 497016),
#  ('with', 466338),
#  ('size', 453835),
#  ('brand', 271092),
#  ('you', 268868),
#  ('free', 267106),
#  ('condition', 255439)]

# %% [markdown]
# ### 5. Removing stopwords and Tokenization

# %%
# show stop words examples

stop_words = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# tokenize helper function
def text_process(raw_text):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(raw_text) if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.lower().split() if word.lower() not in stop_words]


# tokenize message column and create a column for tokens
dsp['tokens'] = dsp['item_description'].apply(text_process) # tokenize style 1

dsp.head()
# Out:
#                                     item_description  item_condition_id  \
# 0                                    description yet                  3
# 1  this keyboard great condition and works like c...                  3
# 2  adorable top with hint lace and key hole the b...                  1
# 3  new with tags leather horses retail for each s...                  1
# 4             complete with certificate authenticity                  1
#
#    word count                                             tokens
# 0           2                                 [description, yet]
# 1          29  [keyboard, great, condition, works, like, came...
# 2          18  [adorable, top, hint, lace, key, hole, back, p...
# 3          27  [new, tags, leather, horses, retail, stand, fo...
# 4           4              [complete, certificate, authenticity]

# %%
# split sentences to get individual words
all_words = []
for line in dsp['tokens']: # try 'tokens'
    all_words.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(all_words)
wordfreq
# Out:
# Counter({'description': 91863,
#          'yet': 85151,
#          'keyboard': 1165,
#          'great': 152937,
#          'condition': 255439,
#          'works': 28291,
#          'like': 114422,
#          'came': 5561,
#          'box': 101506,
#          'ports': 1266,
#          'tested': 8338,
#          'work': 17310,
#          'perfectly': 8222,
#          'lights': 3712,
#          'customizable': 262,
#          'via': 4721,
#          'razer': 65,
#          'synapse': 4,
#          'app': 3402,
#          'adorable': 10071,
#          'top': 65924,
#          'hint': 556,
#          'lace': 22247,
#          'key': 5335,
#          'hole': 4577,
#          'back': 61490,
#          'pale': 2462,
#          'pink': 122339,
#          'also': 44010,
#          'available': 37985,
#          'white': 83112,
#          'new': 497016,
#          'tags': 100914,
#          'leather': 28513,
#          'horses': 297,
#          'retail': 28847,
#          'stand': 4700,
#          'foot': 3167,
#          'high': 40979,
#          'sold': 20274,
#          'pair': 26698,
#          'questions': 40105,
#          'please': 114009,
#          'ask': 49454,
#          'free': 267106,
#          'shipping': 223853,
#          'got': 14313,
#          'storage': 7067,
#          'complete': 6879,
#          'certificate': 353,
#          'authenticity': 2618,
#          'banana': 2829,
#          'republic': 1940,
#          'bottoms': 8624,
#          'candies': 376,
#          'skirt': 11647,
#          'matching': 7387,
#          'blazer': 1299,
#          'amy': 198,
#          'byers': 6,
#          'suit': 5588,
#          'loft': 1054,
#          'cami': 891,
#          'size': 453835,
#          'small': 117308,
#          'straps': 14469,
#          'slightly': 8432,
#          'shortened': 75,
#          'fit': 65024,
#          'besides': 1609,
#          'perfect': 72838,
#          'get': 46447,
#          'three': 12395,
#          'pairs': 14936,
#          'sophie': 124,
#          'cheer': 537,
#          'shorts': 25017,
#          'medium': 77238,
#          'girls': 13641,
#          'two': 37929,
#          'sports': 7453,
#          'bra': 24688,
#          'boy': 5877,
#          'spandex': 10353,
#          'sets': 6237,
#          'items': 80285,
#          'total': 12780,
#          'store': 13639,
#          'take': 22453,
#          'today': 6639,
#          'less': 7163,
#          'price': 145000,
#          'one': 122009,
#          'item': 49317,
#          'plus': 39049,
#          'green': 36536,
#          'realized': 1090,
#          'pants': 22103,
#          'backwards': 130,
#          'picture': 30737,
#          'dirty': 3790,
#          'hand': 15143,
#          'washed': 21238,
#          'stuffed': 1221,
#          'body': 33100,
#          'painted': 1636,
#          'porcelain': 666,
#          'head': 6291,
#          'hands': 4376,
#          'feet': 5125,
#          'clowns': 23,
#          'scary': 199,
#          'tall': 11476,
#          'chips': 2322,
#          'cracks': 3334,
#          'minor': 13609,
#          'paint': 3994,
#          'loss': 3564,
#          'places': 1071,
#          'clown': 120,
#          'circus': 146,
#          'doll': 6036,
#          'collectible': 1480,
#          'full': 40119,
#          '1oz': 1246,
#          'sephora': 6466,
#          'mists': 288,
#          'fresh': 6351,
#          'clean': 21888,
#          'sun': 4084,
#          'kiss': 2409,
#          'cool': 8633,
#          'bright': 7607,
#          'flirt': 342,
#          'sweet': 5601,
#          'flirty': 844,
#          'authentic': 62402,
#          'suede': 6905,
#          'fringe': 2056,
#          'boots': 15943,
#          'sizes': 20167,
#          'love': 27476,
#          'wearing': 6921,
#          'thick': 6909,
#          'socks': 6611,
#          'winter': 7877,
#          'well': 23706,
#          'last': 21199,
#          'brand': 271093,
#          'deluxe': 3578,
#          'travel': 12170,
#          'products': 11468,
#          'contains': 6694,
#          'amazonian': 662,
#          'clay': 2489,
#          'hour': 2839,
#          'blush': 7636,
#          'paaarty': 82,
#          '05oz': 114,
#          'tarteist': 351,
#          'lip': 22673,
#          'birthday': 5720,
#          '034oz': 5,
#          '1ml': 210,
#          'glitter': 8935,
#          'eyeshadows': 1381,
#          'brass': 1914,
#          'bleached': 566,
#          'color': 122822,
#          'coral': 5340,
#          'retails': 19800,
#          'baby': 23970,
#          '’tan': 10,
#          'active': 2058,
#          'made': 38727,
#          'breathable': 2426,
#          'tech': 1251,
#          'performance': 2106,
#          'fabric': 14367,
#          'wicks': 390,
#          'away': 6323,
#          'moisture': 3569,
#          'sweat': 3670,
#          'blocks': 533,
#          'sun’': 12,
#          'harmful': 579,
#          'uva': 586,
#          'uvb': 577,
#          'rays': 456,
#          'provides': 4491,
#          'unique': 7663,
#          'temperature': 1853,
#          'control': 7092,
#          'ergonomic': 525,
#          'positioning': 66,
#          'healthy': 1855,
#          'infant': 2215,
#          'development': 141,
#          'evenly': 692,
#          'distributes': 102,
#          'weight': 15323,
#          'across': 5028,
#          'shoulders': 1743,
#          'double': 9133,
#          'loop': 1281,
#          'design': 23336,
#          'slips': 293,
#          'shirt': 42992,
#          'pallete': 255,
#          'faced': 4986,
#          'mint': 12579,
#          'still': 52572,
#          'original': 39866,
#          'part': 7647,
#          'christmas': 13277,
#          '2016': 4567,
#          'collection': 14041,
#          'pretty': 17218,
#          'eye': 17344,
#          'shadow': 7133,
#          'colors': 39559,
#          'sized': 6099,
#          'better': 9096,
#          'sex': 889,
#          'mascara': 6372,
#          'never': 158825,
#          'even': 12974,
#          'swatched': 10002,
#          'impeccable': 163,
#          'shape': 16973,
#          'includes': 40217,
#          'day': 52088,
#          'priority': 4797,
#          'insurance': 885,
#          'fancy': 749,
#          'dressy': 789,
#          'casual': 3686,
#          'dress': 44174,
#          '100': 55185,
#          'polyester': 14078,
#          'dried': 1746,
#          'lush': 2444,
#          'purchased': 19827,
#          'francesca': 310,
#          'people': 8286,
#          'anthropology': 185,
#          'dry': 14540,
#          'goods': 427,
#          'worn': 186946,
#          'excellent': 47109,
#          'nwt': 34383,
#          'victoria': 42082,
#          'secret': 44413,
#          'ultimate': 4454,
#          'sport': 4226,
#          'maximum': 1629,
#          'support': 6250,
#          '34ddd': 247,
#          'reasonable': 6920,
#          'offers': 25388,
#          'welcomed': 690,
#          'lowest': 10630,
#          'lowball': 1823,
#          'block': 2543,
#          'phone': 28519,
#          'opened': 22397,
#          'mobile': 3628,
#          'unlocked': 2666,
#          'switching': 142,
#          'buttons': 7030,
#          'functioning': 323,
#          'used': 184043,
#          'check': 49313,
#          'reviews': 1515,
#          'honest': 1460,
#          'feedback': 2619,
#          '32gb': 911,
#          'sorry': 6483,
#          'charger': 16715,
#          'included': 40744,
#          'lanascloset': 5,
#          '✨': 8419,
#          'delete': 1530,
#          'update': 2955,
#          'listings': 37461,
#          'relist': 300,
#          '“sold”': 9,
#          'easier': 1273,
#          'access': 2280,
#          'shop': 6514,
#          'later': 1398,
#          'normally': 1909,
#          'ship': 65883,
#          'following': 5385,
#          'happens': 645,
#          'days': 29153,
#          'purchase': 32933,
#          'forever': 12197,
#          'brandy': 7543,
#          'melville': 6770,
#          'baseball': 3002,
#          'tee': 12830,
#          'percent': 1036,
#          'beaters': 107,
#          'lot': 21962,
#          'life': 12904,
#          'otterbox': 1358,
#          'defender': 1039,
#          'iphone': 56855,
#          'time': 34419,
#          'beautiful': 37693,
#          'zips': 1663,
#          'ties': 3174,
#          'cream': 19798,
#          'liner': 7295,
#          'bottom': 26714,
#          '29w': 18,
#          '33l': 26,
#          'social': 576,
#          'stretch': 11463,
#          'hollister': 6959,
#          'jeans': 24153,
#          'see': 48381,
#          'leathers': 51,
#          'tag': 34153,
#          'near': 3271,
#          'belt': 7797,
#          'loops': 759,
#          'tore': 157,
#          'favorite': 6245,
#          'boyfriend': 2486,
#          'bnib': 1784,
#          'waterproof': 8188,
#          'posts': 752,
#          'logo': 15815,
#          'band': 13657,
#          '36d': 1430,
#          'push': 8905,
#          'unused': 10509,
#          'caudalie': 145,
#          'beauty': 13889,
#          'elixir': 321,
#          'mist': 5153,
#          'beanie': 2516,
#          'babies': 1459,
#          'pugsley': 2,
#          'wrinkles': 1895,
#          'puppy': 852,
#          'pumpkin': 2417,
#          'big': 19212,
#          'dog': 8297,
#          'retro': 3631,
#          'pinup': 184,
#          'frilly': 68,
#          'skirted': 68,
#          'barbie': 2081,
#          'pinksuper': 14,
#          'cute': 72386,
#          'fan': 2946,
#          'martini': 109,
#          'cherry': 2630,
#          'anchor': 830,
#          'marabou': 23,
#          'sunny': 377,
#          'san': 1075,
#          'diego': 257,
#          'cali': 263,
#          'fornia': 16,
#          'absolutely': 5141,
#          'soft': 44892,
#          'genuine': 4634,
#          'real': 9523,
#          'bunny': 1331,
#          'fox': 1567,
#          'foxy': 176,
#          'loxy': 14,
#          'fur': 4708,
#          'stunning': 2669,
#          'gorgeous': 14738,
#          'bambi': 318,
#          'long': 46753,
#          'eyelashes': 2724,
#          'cheeks': 488,
#          'juicy': 2478,
#          'dollface': 28,
#          'candy': 6211,
#          'girlfriend': 357,
#          'dance': 1774,
#          'club': 1468,
#          'panty': 3434,
#          'present': 2281,
#          'girl': 14210,
#          'everything': 16970,
#          'cupcake': 996,
#          'couture': 2147,
#          'resin': 876,
#          'kawaii': 1926,
#          'lolita': 466,
#          'gift': 27695,
#          'lime': 2896,
#          'crime': 684,
#          'pegasus': 170,
#          'unicorn': 10037,
#          'flamingo': 819,
#          'swan': 173,
#          'princess': 2978,
#          'kitty': 3110,
#          'rockabilly': 163,
#          'jewelry': 12730,
#          'wild': 3239,
#          'gypsy': 995,
#          'wedding': 4399,
#          'festival': 1419,
#          'edf': 17,
#          'electronic': 617,
#          'rave': 1028,
#          'raver': 42,
#          'coachella': 527,
#          'party': 5710,
#          'fits': 41530,
#          'super': 66144,
#          'capri': 2424,
#          'leggings': 37937,
#          'waist': 24706,
#          '1in': 626,
#          'elastic': 8181,
#          'pre': 7171,
#          'owned': 4803,
#          'light': 48965,
#          'scratches': 17531,
#          'hardware': 5784,
#          'consistent': 184,
#          'gentle': 2280,
#          'use': 44312,
#          'togo': 16,
#          'comes': 67233,
#          'twilly': 64,
#          'wear': 63141,
#          'spots': 4300,
#          'believe': 3221,
#          '500gb': 181,
#          'power': 8340,
#          'cord': 6452,
#          'controller': 3663,
#          'rechargeable': 1577,
#          'pack': 14467,
#          'downloaded': 137,
#          'games': 10141,
#          'scratched': 1108,
#          'affect': 2014,
#          'gameplay': 270,
#          'corest': 1,
#          'bundle': 121235,
#          'save': 54757,
#          'feel': 24980,
#          'kylie': 9747,
#          'happy': 14058,
#          'matte': 21930,
#          'mini': 20950,
#          'lipstick': 15122,
#          'jenner': 2933,
#          'kit': 11114,
#          'pcs': 5678,
#          'leo': 979,
#          'kristen': 895,
#          'dolce': 1714,
#          'expos': 6,
#          'firm': 87273,
#          'disappointed': 342,
#          'generally': 709,
#          'takes': 4925,
#          'usps': 15627,
#          'within': 19057,
#          'hours': 14123,
#          'week': 4189,
#          'buh': 2,
#          'looks': 15002,
#          'ready': 9018,
#          'shipped': 18484,
#          'supper': 238,
#          'tropical': 1413,
#          'print': 25560,
#          'comfy': 13041,
#          'quality': 33019,
#          'called': 1601,
#          'every': 10657,
#          'lightly': 7602,
#          'lined': 7729,
#          'ships': 17960,
#          'seller': 5559,
#          'fee': 4751,
#          'totally': 1071,
#          'masks': 1218,
#          'expired': 436,
#          'feb': 156,
#          'fast': 25735,
#          'find': 17655,
#          'affordable': 1160,
#          'sell': 15865,
#          'make': 46346,
#          'bundles': 15004,
#          'smoking': 4263,
#          'bowl': 2769,
#          'bought': 33224,
#          'ago': 3577,
#          'return': 3443,
#          'things': 4723,
#          'buy': 30503,
#          'piece': 18894,
#          'black': 152652,
#          'outside': 7260,
#          'gray': 24440,
#          'inside': 28745,
#          'warm': 14092,
#          'runs': 6978,
#          'true': 13287,
#          'slime': 10477,
#          'approximately': 5016,
#          'ounces': 2152,
#          'kind': 3788,
#          'sticky': 2781,
#          'air': 11412,
#          'tight': 5084,
#          'container': 3246,
#          'easy': 18525,
#          'scemted': 1,
#          'sparkling': 1149,
#          'blackberry': 696,
#          'woods': 527,
#          'bath': 11378,
#          'shoulder': 12776,
#          'crop': 6572,
#          'euc': 10805,
#          'sleeves': 12258,
#          'rayon': 2562,
#          'actual': 4154,
#          'navy': 24929,
#          'blue': 74671,
#          'stripes': 5132,
#          'let': 22131,
#          'know': 26533,
#          'want': 28400,
#          'pictures': 23958,
#          'measurement': 1405,
#          'sure': 18460,
#          'discount': 14553,
#          'usually': 5113,
#          'monday': 4607,
#          'saturday': 2031,
#          'post': 6917,
#          'office': 4202,
#          '••any': 7,
#          'issues': 3459,
#          'contact': 11961,
#          'soon': 4373,
#          'found': 2788,
#          'issue': 2351,
#          'satisfaction': 1673,
#          'concern': 185,
#          '••': 1086,
#          'younique': 1264,
#          'fiber': 1852,
#          'lash': 3154,
#          'quickly': 2588,
#          'become': 976,
#          'increase': 1829,
#          'lashes': 7921,
#          '300': 1214,
#          'package': 28689,
#          '24hrs': 1076,
#          'large': 69466,
#          'led': 4256,
#          'shoes': 24992,
#          'kids': 12590,
#          'seven': 854,
#          'red': 40426,
#          'purple': 26440,
#          'turquaz': 2,
#          'yellow': 15928,
#          'different': 16841,
#          'flashlight': 400,
#          'options': 1688,
#          'unisex': 5639,
#          'boys': 9830,
#          'carl': 71,
#          'collectibles': 528,
#          'year': 7044,
#          '2000': 770,
#          'mattel': 255,
#          'inc': 675,
#          'elvis': 116,
#          'cars': 1497,
#          'vintage': 15675,
#          'hot': 15474,
#          'rids': 10,
#          'wheels': 934,
#          'colored': 8842,
#          'strapless': 3509,
#          'bandeau': 687,
#          'specific': 1736,
#          'cup': 11657,
#          'message': 24391,
#          '2017': 4257,
#          'rae': 10099,
#          'dunn': 10163,
#          'holiday': 5592,
#          'hugs': 402,
#          'mug': 6551,
#          'another': 7438,
#          'keep': 14878,
#          'give': 11253,
#          'someone': 5448,
#          'special': 6576,
#          'care': 15520,
#          'promptly': 801,
#          'inspect': 919,
#          'order': 18078,
#          'delivered': 1486,
#          'help': 9046,
#          'rating': 4644,
#          'transaction': 1807,
#          'wood': 3057,
#          'necklace': 14642,
#          'earrings': 10003,
#          'broach': 40,
#          'together': 8392,
#          'pure': 5207,
#          'honey': 3406,
#          '5oz': 1965,
#          'stains': 33738,
#          'tears': 10204,
#          'infantino': 82,
#          'target': 3674,
#          '900': 404,
#          'sweatproof': 59,
#          'wireless': 4767,
#          'bluetooth': 7117,
#          'stereo': 1227,
#          'headsets': 187,
#          'earphone': 1161,
#          'diamond': 6024,
#          'engagement': 791,
#          'ring': 15453,
#          'thicker': 1185,
#          'solitaires': 1,
#          'accepted': 2732,
#          'bag': 50181,
#          'french': 1889,
#          'bulldog': 191,
#          'hard': 16344,
#          'background': 7894,
#          'vietnam': 1400,
#          'always': 13626,
#          'bundling': 5776,
#          'distressed': 4483,
#          'levi': 2242,
#          'slim': 6335,
#          'highwaist': 45,
#          'denim': 7236,
#          'images': 893,
#          'men': 29332,
#          'xxl': 3787,
#          'good': 105407,
#          'mark': 4366,
#          'sleeve': 24377,
#          'signed': 817,
#          'italy': 1237,
#          '925': 4870,
#          'lobster': 983,
#          'claw': 495,
#          'closure': 11593,
#          'inches': 26215,
#          'length': 27212,
#          'rarely': 1234,
#          'flaws': 30924,
#          'selling': 25354,
#          'cotton': 21193,
#          'viscose': 502,
#          'polyamide': 290,
#          'angora': 70,
#          'armour': 5372,
#          'half': 8312,
#          'zip': 18442,
#          'jacket': 19256,
#          'awesome': 7688,
#          'med': 3272,
#          '❕please': 42,
#          'ordering❕': 51,
#          '❕❕❕': 51,
#          'ratings': 4083,
#          'cancel❕❕❕': 51,
#          '⏺️provides': 51,
#          'protection': 8374,
#          'drops': 1874,
#          '⏺️price': 51,
#          'extremely': 4304,
#          'ignored': 4358,
#          '⏺️brand': 51,
#          'factory': 5131,
#          'sealed': 23320,
#          'packaging': 19769,
#          '⏺️will': 51,
#          'asap': 3720,
#          '⏺️check': 51,
#          'page': 10666,
#          'variety': 2306,
#          'cases': 11625,
#          '⏺️allow': 51,
#          'tracking': 17677,
#          'overall': 4343,
#          'signs': 12317,
#          'fine': 8535,
#          'fashion': 9329,
#          'type': 8750,
#          'chain': 10354,
#          'china': 2840,
#          'competitive': 206,
#          'warmers': 728,
#          'pictured': 11593,
#          'sample': 4829,
#          'packages': 2378,
#          'highly': 3097,
#          'scented': 3091,
#          'wax': 5195,
#          'melts': 2072,
#          'nib': 2170,
#          'flameless': 218,
#          'electric': 1804,
#          'melt': 851,
#          'tart': 368,
#          'essential': 4448,
#          'oil': 13426,
#          'warmer': 2419,
#          'lamp': 1313,
#          'candle': 4061,
#          'burner': 588,
#          'watt': 495,
#          'bulb': 877,
#          'guaranteed': 5942,
#          'superior': 1760,
#          'safe': 6243,
#          'durable': 6999,
#          'craftsmanship': 184,
#          'home': 66990,
#          'fragrance': 7356,
#          'solutions': 349,
#          'switch': 2425,
#          'amazing': 11325,
#          'scent': 8101,
#          'throw': 2986,
#          'releases': 191,
#          'aroma': 821,
#          'doubles': 441,
#          'night': 7399,
#          'addition': 2742,
#          'room': 5903,
#          'dorm': 655,
#          'business': 17735,
#          'waiting': 432,
#          'area': 5942,
#          'farm': 544,
#          'house': 5833,
#          'ranch': 156,
#          'cabin': 170,
#          'huge': 2707,
#          'selection': 892,
#          'personal': 2591,
#          'individualized': 60,
#          'themes': 150,
#          'decor': 5451,
#          'decorating': 507,
#          'styles': 3585,
#          'compatible': 8228,
#          'tarts': 605,
#          'scentsy': 1737,
#          'bbw': 918,
#          'yankee': 998,
#          'zebra': 2352,
#          'bed': 2728,
#          'beyond': 1024,
#          'pkgs': 78,
#          'scents': 2709,
#          'listed': 12561,
#          'profile': 6912,
#          'additional': 9197,
#          'added': 4347,
#          'per': 8933,
#          'regular': 8346,
#          'ordering': 1051,
#          'visit': 1663,
#          'probably': 3488,
#          'best': 18183,
#          'old': 12903,
#          'extra': 18305,
#          'responsible': 5207,
#          'hold': 13097,
#          'chinese': 501,
#          'come': 25476,
#          'sanitary': 238,
#          'ones': 6197,
#          'cheeky': 1783,
#          'burgundy': 4786,
#          'separately': 4021,
#          'aura': 189,
#          'fluorite': 74,
#          '⋅': 96,
#          'stone': 6067,
#          'grounding': 75,
#          'spiritualizing': 1,
#          'intuition': 84,
#          'look': 32898,
#          'wishing': 54,
#          'connect': 1484,
#          'spirit': 651,
#          'details': 12266,
#          'cleansed': 292,
#          'charged': 1306,
#          '☆': 3493,
#          'blessed': 792,
#          'witchcraft': 212,
#          'witch': 695,
#          'altar': 146,
#          'crystal': 5579,
#          'wiccan': 523,
#          'wicca': 294,
#          'pagan': 413,
#          'artifact': 28,
#          'witchcraftartifact': 6,
#          'chakra': 631,
#          'sent': 2723,
#          'sea': 2634,
#          'wees': 10,
#          'brown': 24721,
#          'sheer': 5990,
#          'flowy': 2908,
#          'flower': 5378,
#          'front': 35671,
#          'without': 26884,
#          'shade': 15230,
#          'cosmetics': 6839,
#          'jamie': 90,
#          'kern': 15,
#          'coverage': 4818,
#          'corrector': 637,
#          'correcting': 628,
#          'looking': 21669,
#          'certain': 1335,
#          'brands': 6205,
#          'meandering': 114,
#          'search': 4833,
#          'using': 6255,
#          'function': 2682,
#          'space': 4042,
#          'plussizemakeup': 127,
#          'bring': 1775,
#          'refine': 351,
#          'category': 364,
#          'mascaras': 491,
#          'loreal': 905,
#          'covergirl': 731,
#          'rimmel': 377,
#          'maybelline': 2066,
#          'eyebrows': 1127,
#          'need': 26861,
#          'create': 6027,
#          'packed': 2282,
#          'convenient': 1958,
#          'follow': 5631,
#          'directions': 1610,
#          'enables': 310,
#          'natural': 14442,
#          'brows': 1030,
#          'harsh': 341,
#          'line': 6324,
#          'enhance': 1266,
#          'features': 14312,
#          'consists': 312,
#          'eyebrow': 2912,
#          'powder': 12097,
#          'stencils': 564,
#          'thin': 5680,
#          'brush': 23884,
#          'applicator': 1736,
#          'apply': 6252,
#          'precisely': 294,
#          'desired': 1551,
#          'effect': 3177,
#          'beaded': 1166,
#          'reddish': 417,
#          'sheet': 4759,
#          'set': 51860,
#          'fading': 5254,
#          'washing': 2069,
#          'fully': 5200,
#          'intact': 1885,
#          'flat': 8682,
#          'pillow': 3946,
#          'fitted': 5000,
#          'hearts': 2939,
#          'cheetah': 2501,
#          'trim': 5811,
#          'queen': 2641,
#          'boxed': 768,
#          'dvd’': 6,
#          'fitness': 1259,
#          'guide': 1866,
#          'meal': 447,
#          'plan': 971,
#          'rotational': 8,
#          'calendar': 971,
#          'include': 11588,
#          'fire': 2025,
#          'ignite': 45,
#          'launch': 167,
#          'rise': 6619,
#          'amplify': 80,
#          'escalate': 3,
#          'conquer': 17,
#          'triumph': 51,
#          'zenith': 15,
#          'apex': 81,
#          'bonus': 1979,
#          'dvd': 4729,
#          'opus': 10,
#          'cast': 627,
#          'moves': 499,
#          'disc': 3991,
#          'dvds': 1461,
#          'ignore': 1137,
#          'insanity': 76,
#          'p90x': 28,
#          'workout': 4957,
#          'abs': 447,
#          'muscles': 455,
#          'bodyshred': 3,
#          'play': 8887,
#          'tops': 5956,
#          'basketball': 1821,
#          'season': 4799,
#          'sin': 183,
#          'anymore': 7117,
#          'holes': 15444,
#          'taken': 7076,
#          'spring': 5931,
#          'summer': 12748,
#          'fall': 9595,
#          'cuffs': 1654,
#          'show': 11328,
#          'letters': 2581,
#          'peeling': 1747,
#          'bnip': 858,
#          'vhtf': 54,
#          'hottest': 283,
#          'toy': 4406,
#          'babygap': 150,
#          'canvas': 3926,
#          'army': 1695,
#          'gently': 20645,
#          'loved': 5586,
#          'lots': 10994,
#          'left': 21320,
#          'wash': 17079,
#          'hang': 2582,
#          'wipe': 1799,
#          'son': 3007,
#          'wore': 16976,
#          'khakis': 221,
#          'church': 278,
#          'groupon': 22,
#          'though': 3810,
#          'system': 4298,
#          'error': 300,
#          'completely': 3896,
#          'second': 6354,
#          'shows': 7434,
#          'cost': 5778,
#          'ordered': 3298,
#          'shades': 9248,
#          'match': 4620,
#          'face': 17928,
#          'primer': 5480,
#          'brightening': 772,
#          'website': 3581,
#          'bling': 4681,
#          'mickey': 2750,
#          'ear': 3829,
#          'case': 52926,
#          'disney': 11856,
#          'trip': 1031,
#          'received': 4138,
#          'many': 13760,
#          'compliments': 1164,
#          'ears': 1800,
#          'stones': 3703,
#          'missing': 11039,
#          'exact': 4287,
#          'barely': 11356,
#          'noticeable': 8507,
#          'strap': 16968,
#          'neck': 13665,
#          ...})

# %% [markdown]
# ### 6. Vectorization and Transformation of Count Matrix

# %%
# vetorize
bow_transformer = CountVectorizer(analyzer=text_process).fit(dsp['item_description'])
# print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 180928

# %%
#entire word vocabulary 
bow_transformer.vocabulary_
# Out:
# {'description': 51531,
#  'yet': 160489,
#  'keyboard': 84918,
#  'great': 70815,
#  'condition': 44904,
#  'works': 158805,
#  'like': 89790,
#  'came': 37686,
#  'box': 33868,
#  'ports': 116300,
#  'tested': 145288,
#  'work': 158753,
#  'perfectly': 112404,
#  'lights': 89689,
#  'customizable': 48615,
#  'via': 154075,
#  'razer': 121295,
#  'synapse': 142985,
#  'app': 24011,
#  'adorable': 20479,
#  'top': 147760,
#  'hint': 75143,
#  'lace': 87165,
#  'key': 84913,
#  'hole': 75527,
#  'back': 27421,
#  'pale': 110429,
#  'pink': 113955,
#  'also': 22213,
#  'available': 26488,
#  'white': 157286,
#  'new': 104133,
#  'tags': 143571,
#  'leather': 88512,
#  'horses': 76109,
#  'retail': 123939,
#  'stand': 138809,
#  'foot': 65117,
#  'high': 74854,
#  'sold': 136288,
#  'pair': 110337,
#  'questions': 120063,
#  'please': 114880,
#  'ask': 25394,
#  'free': 65929,
#  'shipping': 131883,
#  'got': 70284,
#  'storage': 139872,
#  'complete': 44571,
#  'certificate': 39816,
#  'authenticity': 26292,
#  'banana': 28094,
#  'republic': 123467,
#  'bottoms': 33652,
#  'candies': 37937,
#  'skirt': 134253,
#  'matching': 95534,
#  'blazer': 31844,
#  'amy': 22877,
#  'byers': 36759,
#  'suit': 141240,
#  'loft': 91118,
#  'cami': 37738,
#  'size': 133710,
#  'small': 135103,
#  'straps': 140135,
#  'slightly': 134755,
#  'shortened': 132509,
#  'fit': 63679,
#  'besides': 30543,
#  'perfect': 112382,
#  'get': 68607,
#  'three': 146276,
#  'pairs': 110345,
#  'sophie': 136646,
#  'cheer': 40614,
#  'shorts': 132530,
#  'medium': 96749,
#  'girls': 69088,
#  'two': 150339,
#  'sports': 137979,
#  'bra': 34077,
#  'boy': 33962,
#  'spandex': 137077,
#  'sets': 130710,
#  'items': 80984,
#  'total': 148039,
#  'store': 139889,
#  'take': 143711,
#  'today': 147302,
#  'less': 89120,
#  'price': 117489,
#  'one': 107730,
#  'item': 80973,
#  'plus': 115153,
#  'green': 70870,
#  'realized': 121589,
#  'pants': 110746,
#  'backwards': 27560,
#  'picture': 113541,
#  'dirty': 52812,
#  'hand': 72637,
#  'washed': 156063,
#  'stuffed': 140652,
#  'body': 32756,
#  'painted': 110322,
#  'porcelain': 116154,
#  'head': 73718,
#  'hands': 72773,
#  'feet': 62474,
#  'clowns': 42917,
#  'scary': 128573,
#  'tall': 143787,
#  'chips': 41140,
#  'cracks': 47058,
#  'minor': 98958,
#  'paint': 110314,
#  'loss': 91665,
#  'places': 114487,
#  'clown': 42912,
#  'circus': 41890,
#  'doll': 53878,
#  'collectible': 43637,
#  'full': 66775,
#  '1oz': 5413,
#  'sephora': 130430,
#  'mists': 99344,
#  'fresh': 66162,
#  'clean': 42331,
#  'sun': 141397,
#  'kiss': 85537,
#  'cool': 45825,
#  'bright': 34780,
#  'flirt': 64435,
#  'sweet': 142556,
#  'flirty': 64447,
#  'authentic': 26276,
#  'suede': 141106,
#  'fringe': 66337,
#  'boots': 33347,
#  'sizes': 133812,
#  'love': 91820,
#  'wearing': 156509,
#  'thick': 145957,
#  'socks': 136032,
#  'winter': 157985,
#  'well': 156849,
#  'last': 87934,
#  'brand': 34249,
#  'deluxe': 51026,
#  'travel': 148791,
#  'products': 117981,
#  'contains': 45487,
#  'amazonian': 22494,
#  'clay': 42302,
#  'hour': 76267,
#  'blush': 32495,
#  'paaarty': 109973,
#  '05oz': 663,
#  'tarteist': 144168,
#  'lip': 90207,
#  'birthday': 31356,
#  '034oz': 475,
#  '1ml': 5363,
#  'glitter': 69427,
#  'eyeshadows': 60849,
#  'brass': 34349,
#  'bleached': 31869,
#  'color': 43764,
#  'coral': 46026,
#  'retails': 123951,
#  'baby': 27275,
#  '’tan': 163548,
#  'active': 20044,
#  'made': 93633,
#  'breathable': 34539,
#  'tech': 144659,
#  'performance': 112455,
#  'fabric': 61362,
#  'wicks': 157514,
#  'away': 26742,
#  'moisture': 100174,
#  'sweat': 142473,
#  'blocks': 32123,
#  'sun’': 141621,
#  'harmful': 73159,
#  'uva': 152803,
#  'uvb': 152805,
#  'rays': 121276,
#  'provides': 118528,
#  'unique': 151650,
#  'temperature': 144956,
#  'control': 45632,
#  'ergonomic': 59022,
#  'positioning': 116395,
#  'healthy': 73874,
#  'infant': 78963,
#  'development': 51950,
#  'evenly': 59714,
#  'distributes': 53386,
#  'weight': 156744,
#  'across': 19990,
#  'shoulders': 132601,
#  'double': 54289,
#  'loop': 91511,
#  'design': 51600,
#  'slips': 134889,
#  'shirt': 132154,
#  'pallete': 110491,
#  'faced': 61436,
#  'mint': 98985,
#  'still': 139611,
#  'original': 108660,
#  'part': 111082,
#  'christmas': 41481,
#  '2016': 5868,
#  'collection': 43642,
#  'pretty': 117405,
#  'eye': 60714,
#  'shadow': 131035,
#  'colors': 43872,
#  'sized': 133795,
#  'better': 30635,
#  'sex': 130842,
#  'mascara': 95343,
#  'never': 104094,
#  'even': 59705,
#  'swatched': 142426,
#  'impeccable': 78213,
#  'shape': 131223,
#  'includes': 78621,
#  'day': 49853,
#  'priority': 117747,
#  'insurance': 79779,
#  'fancy': 61810,
#  'dressy': 54857,
#  'casual': 39078,
#  'dress': 54816,
#  '100': 1016,
#  'polyester': 115784,
#  'dried': 54894,
#  'lush': 92720,
#  'purchased': 119169,
#  'francesca': 65762,
#  'people': 112236,
#  'anthropology': 23595,
#  'dry': 55159,
#  'goods': 70115,
#  'worn': 158857,
#  'excellent': 60061,
#  'nwt': 106352,
#  'victoria': 154181,
#  'secret': 129775,
#  'ultimate': 150806,
#  'sport': 137955,
#  'maximum': 95925,
#  'support': 141941,
#  '34ddd': 9363,
#  'reasonable': 121674,
#  'offers': 107049,
#  'welcomed': 156823,
#  'lowest': 92027,
#  'lowball': 91987,
#  'block': 32098,
#  'phone': 113203,
#  'opened': 108161,
#  'mobile': 99912,
#  'unlocked': 151781,
#  'switching': 142770,
#  'buttons': 36526,
#  'functioning': 66864,
#  'used': 152572,
#  'check': 40533,
#  'reviews': 124238,
#  'honest': 75821,
#  'feedback': 62415,
#  '32gb': 9047,
#  'sorry': 136727,
#  'charger': 40280,
#  'included': 78571,
#  'lanascloset': 87540,
#  '✨': 175177,
#  'delete': 50892,
#  'update': 152255,
#  'listings': 90564,
#  'relist': 122951,
#  '“sold”': 163873,
#  'easier': 56377,
#  'access': 19682,
#  'shop': 132367,
#  'later': 87978,
#  'normally': 105454,
#  'ship': 131840,
#  'following': 65024,
#  'happens': 72960,
#  'days': 49902,
#  'purchase': 119167,
#  'forever': 65276,
#  'brandy': 34292,
#  'melville': 97104,
#  'baseball': 28628,
#  'tee': 144766,
#  'percent': 112317,
#  'beaters': 29462,
#  'lot': 91681,
#  'life': 89507,
#  'otterbox': 109039,
#  'defender': 50659,
#  'iphone': 80444,
#  'time': 146764,
#  'beautiful': 29544,
#  'zips': 161663,
#  'ties': 146610,
#  'cream': 47260,
#  'liner': 90063,
#  'bottom': 33643,
#  '29w': 7698,
#  '33l': 9227,
#  'social': 136002,
#  'stretch': 140344,
#  'hollister': 75591,
#  'jeans': 82049,
#  'see': 129872,
#  'leathers': 88537,
#  'tag': 143537,
#  'near': 103448,
#  'belt': 30176,
#  'loops': 91521,
#  'tore': 147896,
#  'favorite': 62203,
#  'boyfriend': 33980,
#  'bnib': 32574,
#  'waterproof': 156260,
#  'posts': 116488,
#  'logo': 91155,
#  'band': 28111,
#  '36d': 10144,
#  'push': 119455,
#  'unused': 152150,
#  'caudalie': 39285,
#  'beauty': 29576,
#  'elixir': 57547,
#  'mist': 99309,
#  'beanie': 29385,
#  'babies': 27258,
#  'pugsley': 118907,
#  'wrinkles': 159107,
#  'puppy': 119124,
#  'pumpkin': 119029,
#  'big': 30945,
#  'dog': 53777,
#  'retro': 124084,
#  'pinup': 114150,
#  'frilly': 66329,
#  'skirted': 134257,
#  'barbie': 28362,
#  'pinksuper': 114033,
#  'cute': 48643,
#  'fan': 61789,
#  'martini': 95254,
#  'cherry': 40763,
#  'anchor': 23008,
#  'marabou': 94771,
#  'sunny': 141530,
#  'san': 127674,
#  'diego': 52345,
#  'cali': 37488,
#  'fornia': 65403,
#  'absolutely': 19452,
#  'soft': 136107,
#  'genuine': 68452,
#  'real': 121556,
#  'bunny': 36136,
#  'fox': 65593,
#  'foxy': 65621,
#  'loxy': 92070,
#  'fur': 66973,
#  'stunning': 140701,
#  'gorgeous': 70219,
#  'bambi': 28059,
#  'long': 91284,
#  'eyelashes': 60769,
#  'cheeks': 40603,
#  'juicy': 83307,
#  'dollface': 53894,
#  'candy': 37974,
#  'girlfriend': 69073,
#  'dance': 49417,
#  'club': 42928,
#  'panty': 110761,
#  'present': 117279,
#  'girl': 69065,
#  'everything': 59841,
#  'cupcake': 48373,
#  'couture': 46770,
#  'resin': 123678,
#  'kawaii': 84381,
#  'lolita': 91214,
#  'gift': 68806,
#  'lime': 89939,
#  'crime': 47496,
#  'pegasus': 111979,
#  'unicorn': 151578,
#  'flamingo': 63970,
#  'swan': 142363,
#  'princess': 117680,
#  'kitty': 85628,
#  'rockabilly': 125304,
#  'jewelry': 82412,
#  'wild': 157651,
#  'gypsy': 71967,
#  'wedding': 156617,
#  'festival': 62747,
#  'edf': 56732,
#  'electronic': 57366,
#  'rave': 121174,
#  'raver': 121193,
#  'coachella': 43113,
#  'party': 111146,
#  'fits': 63738,
#  'super': 141642,
#  'capri': 38225,
#  'leggings': 88730,
#  'waist': 155614,
#  '1in': 5284,
#  'elastic': 57240,
#  'pre': 116943,
#  'owned': 109704,
#  'light': 89615,
#  'scratches': 129053,
#  'hardware': 73079,
#  'consistent': 45366,
#  'gentle': 68423,
#  'use': 152563,
#  'togo': 147409,
#  'comes': 44139,
#  'twilly': 150253,
#  'wear': 156487,
#  'spots': 138027,
#  'believe': 30015,
#  '500gb': 12640,
#  'power': 116665,
#  'cord': 46059,
#  'controller': 45650,
#  'rechargeable': 121896,
#  'pack': 110024,
#  'downloaded': 54402,
#  'games': 67660,
#  'scratched': 129049,
#  'affect': 20804,
#  'gameplay': 67655,
#  'corest': 46116,
#  'bundle': 35976,
#  'save': 128214,
#  'feel': 62429,
#  'kylie': 86844,
#  'happy': 72969,
#  'matte': 95701,
#  'mini': 98777,
#  'lipstick': 90352,
#  'jenner': 82188,
#  'kit': 85569,
#  'pcs': 111658,
#  'leo': 89034,
#  'kristen': 86469,
#  'dolce': 53866,
#  'expos': 60488,
#  'firm': 63469,
#  'disappointed': 52839,
#  'generally': 68339,
#  'takes': 143728,
#  'usps': 152691,
#  'within': 158208,
#  'hours': 76274,
#  'week': 156664,
#  'buh': 35775,
#  'looks': 91438,
#  'ready': 121511,
#  'shipped': 131865,
#  'supper': 141909,
#  'tropical': 149402,
#  'print': 117707,
#  'comfy': 44244,
#  'quality': 119878,
#  'called': 37546,
#  'every': 59810,
#  'lightly': 89678,
#  'lined': 90047,
#  'ships': 132085,
#  'seller': 130077,
#  'fee': 62408,
#  'totally': 148052,
#  'masks': 95399,
#  'expired': 60435,
#  'feb': 62377,
#  'fast': 62058,
#  'find': 63221,
#  'affordable': 20851,
#  'sell': 130067,
#  'make': 94102,
#  'bundles': 36009,
#  'smoking': 135421,
#  'bowl': 33836,
#  'bought': 33700,
#  'ago': 21071,
#  'return': 124110,
#  'things': 146033,
#  'buy': 36575,
#  'piece': 113612,
#  'black': 31551,
#  'outside': 109289,
#  'gray': 70767,
#  'inside': 79526,
#  'warm': 155941,
#  'runs': 126592,
#  'true': 149488,
#  'slime': 134778,
#  'approximately': 24236,
#  'ounces': 109104,
#  'kind': 85348,
#  'sticky': 139564,
#  'air': 21269,
#  'tight': 146659,
#  'container': 45477,
#  'easy': 56418,
#  'scemted': 128604,
#  'sparkling': 137175,
#  'blackberry': 31563,
#  'woods': 158650,
#  'bath': 28792,
#  'shoulder': 132589,
#  'crop': 47685,
#  'euc': 59571,
#  'sleeves': 134648,
#  'rayon': 121265,
#  'actual': 20075,
#  'navy': 103316,
#  'blue': 32327,
#  'stripes': 140462,
#  'let': 89142,
#  'know': 85976,
#  'want': 155863,
#  'pictures': 113553,
#  'measurement': 96567,
#  'sure': 142034,
#  'discount': 52952,
#  'usually': 152713,
#  'monday': 100429,
#  'saturday': 128141,
#  'post': 116437,
#  'office': 107122,
#  '••any': 167979,
#  'issues': 80889,
#  'contact': 45464,
#  'soon': 136590,
#  'found': 65529,
#  'issue': 80886,
#  'satisfaction': 128105,
#  'concern': 44809,
#  '••': 167969,
#  'younique': 160827,
#  'fiber': 62882,
#  'lash': 87864,
#  'quickly': 120116,
#  'become': 29689,
#  'increase': 78723,
#  'lashes': 87879,
#  '300': 8397,
#  'package': 110031,
#  '24hrs': 6814,
#  'large': 87759,
#  'led': 88613,
#  'shoes': 132294,
#  'kids': 85151,
#  'seven': 130782,
#  'red': 122118,
#  'purple': 119363,
#  'turquaz': 150064,
#  'yellow': 160406,
#  'different': 52380,
#  'flashlight': 64050,
#  'options': 108343,
#  'unisex': 151668,
#  'boys': 33994,
#  'carl': 38592,
#  'collectibles': 43638,
#  'year': 160356,
#  '2000': 5752,
#  'mattel': 95709,
#  'inc': 78451,
#  'elvis': 57708,
#  'cars': 38774,
#  'vintage': 154431,
#  'hot': 76168,
#  'rids': 124685,
#  'wheels': 157145,
#  'colored': 43812,
#  'strapless': 140123,
#  'bandeau': 28133,
#  'specific': 137316,
#  'cup': 48367,
#  'message': 97567,
#  '2017': 5875,
#  'rae': 120596,
#  'dunn': 55540,
#  'holiday': 75546,
#  'hugs': 76610,
#  'mug': 101791,
#  'another': 23508,
#  'keep': 84570,
#  'give': 69147,
#  'someone': 136460,
#  'special': 137285,
#  'care': 38480,
#  'promptly': 118217,
#  'inspect': 79587,
#  'order': 108480,
#  'delivered': 50966,
#  'help': 74304,
#  'rating': 121121,
#  'transaction': 148604,
#  'wood': 158617,
#  'necklace': 103524,
#  'earrings': 56299,
#  'broach': 34981,
#  'together': 147391,
#  'pure': 119250,
#  'honey': 75826,
#  '5oz': 13880,
#  'stains': 138728,
#  'tears': 144617,
#  'infantino': 78968,
#  'target': 144108,
#  '900': 17779,
#  'sweatproof': 142513,
#  'wireless': 158064,
#  'bluetooth': 32409,
#  'stereo': 139426,
#  'headsets': 73814,
#  'earphone': 56284,
#  'diamond': 52189,
#  'engagement': 58438,
#  'ring': 124824,
#  'thicker': 145965,
#  'solitaires': 136369,
#  'accepted': 19659,
#  'bag': 27679,
#  'french': 66122,
#  'bulldog': 35851,
#  'hard': 73013,
#  'background': 27469,
#  'vietnam': 154272,
#  'always': 22337,
#  'bundling': 36085,
#  'distressed': 53369,
#  'levi': 89239,
#  'slim': 134771,
#  'highwaist': 74962,
#  'denim': 51158,
#  'images': 78027,
#  'men': 97179,
#  'xxl': 160030,
#  'good': 70075,
#  'mark': 95043,
#  'sleeve': 134637,
#  'signed': 133052,
#  'italy': 80944,
#  '925': 18043,
#  'lobster': 91013,
#  'claw': 42288,
#  'closure': 42808,
#  'inches': 78491,
#  'length': 88943,
#  'rarely': 121034,
#  'flaws': 64174,
#  'selling': 130105,
#  'cotton': 46517,
#  'viscose': 154565,
#  'polyamide': 115763,
#  'angora': 23262,
#  'armour': 24878,
#  'half': 72430,
#  'zip': 161606,
#  'jacket': 81435,
#  'awesome': 26759,
#  'med': 96649,
#  '❕please': 177173,
#  'ordering❕': 108487,
#  '❕❕❕': 177179,
#  'ratings': 121122,
#  'cancel❕❕❕': 37903,
#  '⏺️provides': 169040,
#  'protection': 118412,
#  'drops': 55060,
#  '⏺️price': 169039,
#  'extremely': 60678,
#  'ignored': 77748,
#  '⏺️brand': 169037,
#  'factory': 61524,
#  'sealed': 129555,
#  'packaging': 110063,
#  '⏺️will': 169041,
#  'asap': 25221,
#  '⏺️check': 169038,
#  'page': 110214,
#  'variety': 153303,
#  'cases': 38912,
#  '⏺️allow': 169036,
#  'tracking': 148383,
#  'overall': 109408,
#  'signs': 133076,
#  'fine': 63251,
#  'fashion': 62005,
#  'type': 150421,
#  'chain': 39962,
#  'china': 41056,
#  'competitive': 44535,
#  'warmers': 155947,
#  'pictured': 113545,
#  'sample': 127624,
#  'packages': 110039,
#  'highly': 74929,
#  'scented': 128630,
#  'wax': 156348,
#  'melts': 97099,
#  'nib': 104482,
#  'flameless': 63958,
#  'electric': 57333,
#  'melt': 97084,
#  'tart': 144157,
#  'essential': 59337,
#  'oil': 107281,
#  'warmer': 155946,
#  'lamp': 87508,
#  'candle': 37945,
#  'burner': 36244,
#  'watt': 156304,
#  'bulb': 35813,
#  'guaranteed': 71484,
#  'superior': 141758,
#  'safe': 127148,
#  'durable': 55633,
#  'craftsmanship': 47086,
#  'home': 75687,
#  'fragrance': 65694,
#  'solutions': 136416,
#  'switch': 142758,
#  'amazing': 22472,
#  'scent': 128622,
#  'throw': 146349,
#  'releases': 122890,
#  'aroma': 24938,
#  'doubles': 54300,
#  'night': 104639,
#  'addition': 20245,
#  'room': 125699,
#  'dorm': 54200,
#  'business': 36339,
#  'waiting': 155671,
#  'area': 24621,
#  'farm': 61930,
#  'house': 76301,
#  'ranch': 120889,
#  'cabin': 37143,
#  'huge': 76577,
#  'selection': 130024,
#  'personal': 112692,
#  'individualized': 78849,
#  'themes': 145702,
#  'decor': 50487,
#  'decorating': 50495,
#  'styles': 140784,
#  'compatible': 44502,
#  'tarts': 144198,
#  'scentsy': 128654,
#  'bbw': 29138,
#  'yankee': 160245,
#  'zebra': 161364,
#  'bed': 29701,
#  'beyond': 30727,
#  'pkgs': 114436,
#  'scents': 128647,
#  'listed': 90526,
#  'profile': 118044,
#  'additional': 20246,
#  'added': 20209,
#  'per': 112301,
#  'regular': 122667,
#  'ordering': 108486,
#  'visit': 154599,
#  'probably': 117844,
#  'best': 30559,
#  'old': 107422,
#  'extra': 60630,
#  'responsible': 123808,
#  'hold': 75457,
#  'chinese': 41076,
#  'come': 44113,
#  'sanitary': 127823,
#  'ones': 107773,
#  'cheeky': 40608,
#  'burgundy': 36208,
#  'separately': 130365,
#  'aura': 26184,
#  'fluorite': 64743,
#  '⋅': 168989,
#  'stone': 139808,
#  'grounding': 71258,
#  'spiritualizing': 137719,
#  'intuition': 80179,
#  'look': 91399,
#  'wishing': 158120,
#  'connect': 45221,
#  'spirit': 137709,
#  'details': 51795,
#  'cleansed': 42380,
#  'charged': 40275,
#  '☆': 171112,
#  'blessed': 31950,
#  'witchcraft': 158154,
#  'witch': 158151,
#  'altar': 22236,
#  'crystal': 47992,
#  'wiccan': 157494,
#  'wicca': 157493,
#  'pagan': 110210,
#  'artifact': 25129,
#  'witchcraftartifact': 158155,
#  'chakra': 40004,
#  'sent': 130320,
#  'sea': 129491,
#  'wees': 156712,
#  'brown': 35203,
#  'sheer': 131458,
#  'flowy': 64672,
#  'flower': 64630,
#  'front': 66450,
#  'without': 158222,
#  'shade': 130980,
#  'cosmetics': 46395,
#  'jamie': 81657,
#  'kern': 84817,
#  'coverage': 46796,
#  'corrector': 46253,
#  'correcting': 46245,
#  'looking': 91415,
#  'certain': 39811,
#  'brands': 34282,
#  'meandering': 96531,
#  'search': 129630,
#  'using': 152669,
#  'function': 66844,
#  'space': 136987,
#  'plussizemakeup': 115189,
#  'bring': 34868,
#  'refine': 122415,
#  'category': 39163,
#  'mascaras': 95346,
#  'loreal': 91603,
#  'covergirl': 46818,
#  'rimmel': 124798,
#  'maybelline': 95998,
#  'eyebrows': 60724,
#  'need': 103613,
#  'create': 47320,
#  'packed': 110084,
#  'convenient': 45701,
#  'follow': 65018,
#  'directions': 52777,
#  'enables': 58191,
#  'natural': 103194,
#  'brows': 35234,
#  'harsh': 73231,
#  'line': 90040,
#  'enhance': 58484,
#  'features': 62349,
#  'consists': 45370,
#  'eyebrow': 60723,
#  'powder': 116639,
#  'stencils': 139352,
#  'thin': 146020,
#  'brush': 35334,
#  'applicator': 24144,
#  'apply': 24172,
#  'precisely': 116996,
#  'desired': 51669,
#  'effect': 56941,
#  'beaded': 29326,
#  'reddish': 122146,
#  'sheet': 131475,
#  'set': 130687,
#  'fading': 61550,
#  'washing': 156077,
#  'fully': 66807,
#  'intact': 79797,
#  'flat': 64072,
#  'pillow': 113835,
#  'fitted': 63759,
#  'hearts': 73950,
#  'cheetah': 40650,
#  'trim': 149178,
#  'queen': 120011,
#  'boxed': 33884,
#  'dvd’': 55811,
#  'fitness': 63730,
#  'guide': 71606,
#  'meal': 96517,
#  'plan': 114548,
#  'rotational': 125963,
#  'calendar': 37460,
#  'include': 78568,
#  'fire': 63397,
#  'ignite': 77740,
#  'launch': 88073,
#  'rise': 124960,
#  'amplify': 22822,
#  'escalate': 59185,
#  'conquer': 45285,
#  'triumph': 149312,
#  'zenith': 161428,
#  'apex': 23916,
#  'bonus': 33134,
#  'dvd': 55800,
#  'opus': 108370,
#  'cast': 39039,
#  'moves': 101403,
#  'disc': 52867,
#  'dvds': 55805,
#  'ignore': 77747,
#  'insanity': 79461,
#  'p90x': 109958,
#  'workout': 158791,
#  'abs': 19430,
#  'muscles': 102133,
#  'bodyshred': 32814,
#  'play': 114730,
#  'tops': 147840,
#  'basketball': 28702,
#  'season': 129660,
#  'sin': 133443,
#  'anymore': 23783,
#  'holes': 75531,
#  'taken': 143717,
#  'spring': 138108,
#  'summer': 141341,
#  'fall': 61714,
#  'cuffs': 48268,
#  'show': 132631,
#  'letters': 89183,
#  'peeling': 111935,
#  'bnip': 32578,
#  'vhtf': 154053,
#  'hottest': 76228,
#  'toy': 148274,
#  'babygap': 27313,
#  'canvas': 38092,
#  'army': 24914,
#  'gently': 68443,
#  'loved': 91846,
#  'lots': 91713,
#  'left': 88666,
#  'wash': 156032,
#  'hang': 72837,
#  'wipe': 158027,
#  'son': 136508,
#  'wore': 158741,
#  'khakis': 85023,
#  'church': 41640,
#  'groupon': 71273,
#  'though': 146214,
#  'system': 143084,
#  'error': 59090,
#  'completely': 44575,
#  'second': 129756,
#  'shows': 132684,
#  'cost': 46438,
#  'ordered': 108482,
#  'shades': 131001,
#  'match': 95517,
#  'face': 61424,
#  'primer': 117634,
#  'brightening': 34789,
#  'website': 156605,
#  'bling': 32013,
#  'mickey': 98057,
#  'ear': 56227,
#  'case': 38888,
#  'disney': 53155,
#  'trip': 149238,
#  'received': 121850,
#  'many': 94724,
#  'compliments': 44619,
#  'ears': 56317,
#  'stones': 139818,
#  'missing': 99260,
#  'exact': 59994,
#  'barely': 28419,
#  'noticeable': 105660,
#  'strap': 140107,
#  'neck': 103506,
#  ...}

# %%
# transform the entire DataFrame of messages
sentiment_text_bow = bow_transformer.transform(dsp['item_description'])

# check out the bag-of-words counts for the entire corpus as a large sparse matrix
print('Shape of Sparse Matrix: ', sentiment_text_bow.shape)
print('Amount of Non-Zero occurences: ', sentiment_text_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (1482535, 180928)
# Amount of Non-Zero occurences:  21861730

# %%
# from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(sentiment_text_bow)

# to transform the entire bag-of-words corpus
sentiment_text_tfidf = tfidf_transformer.transform(sentiment_text_bow)
print(sentiment_text_tfidf.shape)
# Out:
# (1482535, 180928)

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
# Run Train Data Through Pipeline analyzer=text_process
# uncomment below to train on a larger dataset but it is very slow for a regular laptop

X_train, X_test, y_train, y_test = train_test_split(dsp['item_description'][:100000], dsp['binary item condition'][:100000], test_size=0.2)



# create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(strip_accents='ascii',
                            stop_words='english',
                            lowercase=True)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# this is where we define the values for GridSearchCV to iterate over
parameters = {'bow__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'classifier__alpha': (1e-2, 1e-3),
             }

# do 2-fold cross validation for each of the 8 possible combinations of the above params
grid = GridSearchCV(pipeline, cv=2, param_grid=parameters, verbose=1)
grid.fit(X_train,y_train)

# summarize results
print("\nBest Model: %f using %s" % (grid.best_score_, grid.best_params_))
print('\n')
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
params = grid.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean: %f Stdev:(%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  1.0min finished
# Best Model: 0.793175 using {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
#
#
# Mean: 0.772887 Stdev:(0.000093) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.787512 Stdev:(0.000207) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.768687 Stdev:(0.000518) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.782787 Stdev:(0.000032) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}
# Mean: 0.779125 Stdev:(0.000481) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.793175 Stdev:(0.000170) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.769188 Stdev:(0.001243) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.785212 Stdev:(0.000643) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}

# %%
# save best model to current working directory
joblib.dump(grid, "item_description_sentiment.pkl")
# Out:
# ['item_description_sentiment.pkl']

# %% [markdown]
# #### Accuracy Score and Confusion Matrix

# %%
# load from file and predict using the best configs found in the CV step
model_NB = joblib.load("item_description_sentiment.pkl" )

# get predictions from best model above
y_preds = model_NB.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds))
print('\n')
print(classification_report(y_test, y_preds))
# Out:
# accuracy score:  0.79595
#
#
# confusion matrix:
#  [[12038  1723]
#  [ 2358  3881]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86     13761
#            1       0.69      0.62      0.66      6239
#
#    micro avg       0.80      0.80      0.80     20000
#    macro avg       0.76      0.75      0.76     20000
# weighted avg       0.79      0.80      0.79     20000

# %% [markdown]
# ### Linear Support Vector Classifier

# %%
from sklearn.svm import SVC
X_train, X_test, y_train, y_test = train_test_split(dsp['item_description'][:80000], dsp['binary item condition'][:80000], test_size=0.2)

text_clf_SVC = Pipeline([('bow', CountVectorizer(strip_accents='ascii',stop_words='english',lowercase=True)),
                     ('tfidf', TfidfTransformer()),
                     ('classifier', SVC(kernel='linear')),
])
text_clf_SVC.fit(X_train, y_train)
print('Done!')
# Out:
# Done!

# %% [markdown]
# #### Accuracy Score and Confusion Matrix

# %%
# get predictions from best model above
y_preds_SVC = text_clf_SVC.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds_SVC))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds_SVC))
print('\n')
print(classification_report(y_test, y_preds_SVC))
# Out:
# accuracy score:  0.805125
#
#
# confusion matrix:
#  [[9928 1092]
#  [2026 2954]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86     11020
#            1       0.73      0.59      0.65      4980
#
#    micro avg       0.81      0.81      0.81     16000
#    macro avg       0.78      0.75      0.76     16000
# weighted avg       0.80      0.81      0.80     16000
