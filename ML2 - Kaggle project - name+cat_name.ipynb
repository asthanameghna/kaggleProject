# %%
import csv, string, re, time, nltk, sys
import numpy as np
import pandas as pd
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression

# Uncomment if you haven't downloaded nltk stopwords
# nltk.download('stopwords')
stopwords = stopwords.words('english') # Stopwords = common words, useful to filter them out)

# %% [markdown]
# ### Parse data

# %%
def tsv_parser(filename, delimiter='\t', encoding='utf-8'):
    with open(filename, 'r', encoding=encoding) as tsv_file:
        tsv_reader = csv.reader(tsv_file, delimiter=delimiter)
        df = pd.DataFrame(data=list(tsv_reader))
    return df

# Using function to extract the data from the files
print('Parsing data from TSV file...')
start_time = time.time()
df = tsv_parser('train.tsv')
print(f'Done. Took {time.time()-start_time:.2f}s')
# Out:
# Parsing data from TSV file...
# Done. Took 8.61s

# %% [markdown]
# ### Prepare data

# %%
# Use first row for column names, then drop it from the data
df.columns = df.iloc[0]
df = df.reindex(df.index.drop(0))

# Could either use train_id for the index, or drop it and stick to pandas' index. Uncomment as appropriate.
# df.set_index('train_id', inplace=True) # Use train_id as the index
del df['train_id'] # Drop train id

df.head()
# Out:
# 0                                 name item_condition_id  \
# 1  MLB Cincinnati Reds T Shirt Size XL                 3
# 2     Razer BlackWidow Chroma Keyboard                 3
# 3                       AVA-VIV Blouse                 1
# 4                Leather Horse Statues                 1
# 5                 24K GOLD plated rose                 1
#
# 0                                      category_name brand_name price  \
# 1                                  Men/Tops/T-shirts             10.0
# 2  Electronics/Computers & Tablets/Components & P...      Razer  52.0
# 3                        Women/Tops & Blouses/Blouse     Target  10.0
# 4                 Home/Home Décor/Home Décor Accents             35.0
# 5                            Women/Jewelry/Necklaces             44.0
#
# 0 shipping                                   item_description
# 1        1                                 No description yet
# 2        0  This keyboard is in great condition and works ...
# 3        1  Adorable top with a hint of lace and a key hol...
# 4        1  New with tags. Leather horses. Retail for [rm]...
# 5        0          Complete with certificate of authenticity

# %%
# We will now split the dataframe into X (features/inputs) and y (target variable).
y = df.loc[:, 'price']
y = pd.to_numeric(y)
y.head()
# Out:
# 1    10.0
# 2    52.0
# 3    10.0
# 4    35.0
# 5    44.0
# Name: price, dtype: float64

# %%
X = df
del X['price']
X.head()
# Out:
# 0                                 name item_condition_id  \
# 1  MLB Cincinnati Reds T Shirt Size XL                 3
# 2     Razer BlackWidow Chroma Keyboard                 3
# 3                       AVA-VIV Blouse                 1
# 4                Leather Horse Statues                 1
# 5                 24K GOLD plated rose                 1
#
# 0                                      category_name brand_name shipping  \
# 1                                  Men/Tops/T-shirts                   1
# 2  Electronics/Computers & Tablets/Components & P...      Razer        0
# 3                        Women/Tops & Blouses/Blouse     Target        1
# 4                 Home/Home Décor/Home Décor Accents                   1
# 5                            Women/Jewelry/Necklaces                   0
#
# 0                                   item_description
# 1                                 No description yet
# 2  This keyboard is in great condition and works ...
# 3  Adorable top with a hint of lace and a key hol...
# 4  New with tags. Leather horses. Retail for [rm]...
# 5          Complete with certificate of authenticity

# %%
from collections import defaultdict

num_categories_dict = defaultdict(int)
for i, category in enumerate(X['category_name']):
    categories = category.split('/')
    num_categories = len(categories)
    if categories[0] != '':
        num_categories_dict[num_categories] += 1
    else:
        num_categories_dict['null'] += 1
#     if num_categories > 3:
#         print(num_categories, category)
        
print(num_categories_dict)
for k,v in num_categories_dict.items():
    print(f'Number of entries with {k} categories: {v}')
# Out:
# defaultdict(<class 'int'>, {3: 1471819, 'null': 6327, 5: 3059, 4: 1330})
# Number of entries with 3 categories: 1471819
# Number of entries with null categories: 6327
# Number of entries with 5 categories: 3059
# Number of entries with 4 categories: 1330

# %%
def format_string(s):
    """
    Takes a string as input and 'cleans' it.
    """
    # Lowercase
    s = s.lower()
    # Remove hyperlinks
    s = re.sub(r'https?:\/\/.*\/\w*', '', s)
    # Replace hyphens with a space
    s = s.replace('-', ' ')
    # Remove punctuation (important that we removed usernames & hyperlinks before this stage)
    s = re.sub(r'[^\w\s]', '', s)
    # Remove words with <=2 letters
    s = re.sub(r'\b\w{1,2}\b', '', s)
    # Replace excess whitespace with a single space, then strip the whitespace on the edges of the string
    s = re.sub(r'\s\s+', ' ', s)
    s = s.strip() 
    return s

# %%
# Choose how much of the dataset to use (e.g. N=5000 means use first 5k entries). Set = len(X) to use full dataset.
#n = len(X)
n = 5000 # we use first the first 'n' entries (use a low value for fast testing)

# We will store our cleaned strings in these variables (one for each column we are cleaning).
names_clean = np.empty(n, dtype='U50')
categories_clean = np.empty((n,3), dtype='U50')

start_time = time.time()
print('Cleaning data...')

counter = 10000
# For each row...
for i in range(len(X[:n])):
    row = X.iloc[i].loc[['name', 'category_name']] # row[0] = name, row[1] = category_name
    for col in range(len(row)):
        if col == 0:
            item = row[col]
            body_tokens = []
            # Format the name column
            tokens = format_string(item).split(' ')
            # If nothing is in this part of the tweet after formatting, can skip to next item
            if tokens[0] == '':
                continue
            else:
                # Filter tokens in the tweet item to remove stopwords & tokens that contain non-alphabet characters
                tokens = [t for t in tokens if t not in stopwords and t.isalpha()]
                # Put the tokens back together as one string
                joined_string = ' '.join(tokens)
                # Append it to the items in the body
                # (this is necessary because some tweets have their text body split into multiple items)
                body_tokens.append(joined_string)
            # Join the body into one string
            body = ' '.join(body_tokens)
            names_clean[i] = body
        else:
            category_name = row[col]
            categories = category_name.split('/')
            num_categories = len(categories)
            if num_categories < 3:
                categories_clean[i,:] = np.nan, np.nan, np.nan
            else:
                categories_clean[i,:] = categories[:3] # only use the first three categories -> ignore further subcategories

    
    # Every 1k iterations, update progress bar (or if we are about to finish).
    if counter == 10000 or i == n-1:
        j = (i + 1) / n
        sys.stdout.write('\r')
        sys.stdout.write("[%-20s] %d%%" % ('='*int(20*j), 100*j))
        sys.stdout.flush()
        # Reset counter.
        counter = 0   
    counter += 1
    
print(f'\nDone. Took {time.time()-start_time:.2f}s')
# Out:
# Cleaning data...
# [====================] 100%
# Done. Took 3.19s

# %%
# Put cleaned data into a new "cleaned" dataframe.
X_clean = X[:n]

X_clean.loc[:, 'name'] = names_clean

X_clean.loc[:, 'category1'] = categories_clean[:,0]
X_clean.loc[:, 'category2'] = categories_clean[:,1]
X_clean.loc[:, 'category3'] = categories_clean[:,2]

del X_clean['category_name']
# Out:
# /Users/Marcus/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# /Users/Marcus/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/Marcus/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 0                                     name item_condition_id  \
# 1           mlb cincinnati reds shirt size                 3
# 2         razer blackwidow chroma keyboard                 3
# 3                           ava viv blouse                 1
# 4                    leather horse statues                 1
# 5                         gold plated rose                 1
# 6             bundled items requested ruie                 3
# 7       acacia pacific tides santorini top                 3
# 8              girls cheer tumbling bundle                 3
# 9                    girls nike pro shorts                 3
# 10  porcelain clown doll checker pants vtg                 3
# 11                         smashbox primer                 2
# 12                          new body mists                 1
# 13                      black skater dress                 2
# 14                        sharpener eraser                 1
# 15                   hold minnetonka boots                 3
# 16             sephora tarte birthday gift                 1
# 17                       glitter eyeshadow                 1
# 18       new baby ktan active baby carrier                 1
# 19           faced limited merry macaroons                 1
# 20           cream beige front cross shirt                 2
# 21         torrid nautical peplum tube top                 3
# 22                 nwt ultimate sports bra                 1
# 23                    galaxy edge unlocked                 3
# 24                      triple car charger                 1
# 25                  black red baseball tee                 2
# 26                      air jordan carmine                 3
# 27           otterbox defender iphone plus                 1
# 28          lularoe black white polka dots                 3
# 29                 floral romper strapless                 2
# 30                           kendra bundle                 3
# 31                faced better sex mascara                 1
# 32              new lularoe leggings stars                 1
# 33                                pink bra                 1
# 34            caudalíe beauty elixir spray                 1
# 35           four puppy dog stuffed animal                 3
# 36   black capri leggings flowers one size                 1
# 37                               black bag                 3
# 38          armour maroon gray shirt metal                 4
# 39                                xbox one                 3
# 40              victoria secret corest top                 3
# 41                  kylie birthday edition                 1
# 42          tropical flower print bra pink                 3
# 43   lots korean nature republic face mask                 1
# 44          apricot beige stick foundation                 1
# 45                    glass christmas bowl                 2
# 46           womans north face puffer vest                 3
# 47          metallic purple slime sparkles                 1
# 48       brandy melville shoulder crop top                 2
# 49                   lululemon wunder crop                 3
# 50             younique fiber lash mascara                 1
#
# 0            brand_name shipping  \
# 1                              1
# 2                 Razer        0
# 3                Target        1
# 4                              1
# 5                              0
# 6                              0
# 7       Acacia Swimwear        0
# 8                 Soffe        1
# 9                  Nike        0
# 10                             0
# 11             Smashbox        1
# 12    Victoria's Secret        0
# 13                  rue        0
# 14           Scholastic        1
# 15        UGG Australia        0
# 16                Tarte        1
# 17           Wet n Wild        1
# 18                             1
# 19            Too Faced        1
# 20        Anthropologie        0
# 21               Torrid        1
# 22    Victoria's Secret        0
# 23              Samsung        0
# 24                             1
# 25           FOREVER 21        0
# 26           Air Jordan        0
# 27                Apple        1
# 28              LuLaRoe        0
# 29           FOREVER 21        1
# 30            Hollister        1
# 31            Too Faced        1
# 32                             1
# 33                 PINK        0
# 34              Sephora        1
# 35                             1
# 36                             1
# 37                             0
# 38         Under Armour        1
# 39                 Xbox        0
# 40    Victoria's Secret        0
# 41      Kylie Cosmetics        1
# 42                 PINK        1
# 43                             1
# 44                             1
# 45                             1
# 46       The North Face        0
# 47                             0
# 48      Brandy Melville        0
# 49  lululemon athletica        0
# 50                             1
#
# 0                                    item_description               category1  \
# 1                                  No description yet                     Men
# 2   This keyboard is in great condition and works ...             Electronics
# 3   Adorable top with a hint of lace and a key hol...                   Women
# 4   New with tags. Leather horses. Retail for [rm]...                    Home
# 5           Complete with certificate of authenticity                   Women
# 6   Banana republic bottoms, Candies skirt with ma...                   Women
# 7   Size small but straps slightly shortened to fi...                   Women
# 8   You get three pairs of Sophie cheer shorts siz...       Sports & Outdoors
# 9    Girls Size small Plus green. Three shorts total.       Sports & Outdoors
# 10  I realized his pants are on backwards after th...  Vintage & Collectibles
# 11       0.25 oz Full size is 1oz for [rm] in Sephora                  Beauty
# 12  (5) new vs pink body mists (2.5 oz each) Fresh...                  Beauty
# 13                                Xl, great condition                   Women
# 14                                 No description yet                   Other
# 15  Authentic. Suede fringe boots. Great condition...                   Women
# 16  Brand new. Deluxe travel size products. Contai...                  Beauty
# 17  2 glitter eyeshadows; one in Brass and one in ...                  Beauty
# 18  Brand new in box Size: Medium Color: Coral Ret...                    Kids
# 19  This AUTHENTIC pallete by Too Faced is brand n...                  Beauty
# 20  Fancy, dressy or casual! Dress it up or down 1...                   Women
# 21             Size 1. Worn once. Excellent condition                   Women
# 22  NWT Victoria's Secret ULTIMATE SPORT BRA -MAXI...                   Women
# 23  Reasonable offers welcomed. But if you ask "lo...             Electronics
# 24  Brand new never used All colors are available ...             Electronics
# 25  lanascloset ~~~ description: never worn! ✨ i d...                   Women
# 26  They are 100 percent authentic. They are beate...                     Men
# 27  Brand new Otterbox Defender iPhone 6 Plus/6s Plus             Electronics
# 28                 Worn one time. Excellent condition                   Women
# 29  Beautiful Excellent condition Zips and ties in...                   Women
# 30  29w. X 33l. Social stretch hollister jeans ***...                   Women
# 31  BNIB 3 for [rm] Better Than Sex Waterproof Mas...                  Beauty
# 32                                 No description yet                   Women
# 33               Pink bra with logo band! 36d push up                   Women
# 34  New unused and authentic. Caudalie beauty elix...                  Beauty
# 35  2 beanie babies pugsley wrinkles Puppy with pu...                    Kids
# 36  One size fits sizes 2-12 92% polyester 8% span...                   Women
# 37  Pre-owned. Some light scratches on hardware co...                   Women
# 38  Has some wear to the back, and few white spots...                     Men
# 39  500GB Comes with power cord One controller wit...             Electronics
# 40  Victoria secret 34 c corest top Will bundle to...                   Women
# 41  Kylie Happy Birthday Matte Mini Lipstick Kylie...                  Beauty
# 42  Used buh looks brand new and is washed and rea...                   Women
# 43         totally 36 masks, will be expired on Feb..                  Beauty
# 44  Great quality!!! Fast free shipping!! You can ...                  Beauty
# 45  Brand new! Never used smoking bowl. Just bough...  Vintage & Collectibles
# 46  Black outside medium gray inside. Authentic, s...                   Women
# 47  This slime is approximately 1.5 ounces, very s...                    Kids
# 48  Brandy Melville Off Shoulder Crop Top. One Siz...                   Women
# 49  Perfect condition! Super comfy, let me know if...                   Women
# 50  Younique 3d fiber lash mascara will quickly be...                  Beauty
#
# 0                   category2                  category3
# 1                        Tops                   T-shirts
# 2         Computers & Tablets         Components & Parts
# 3              Tops & Blouses                     Blouse
# 4                  Home Décor         Home Décor Accents
# 5                     Jewelry                  Necklaces
# 6                       Other                      Other
# 7                    Swimwear                  Two-Piece
# 8                     Apparel                      Girls
# 9                     Apparel                      Girls
# 10               Collectibles                       Doll
# 11                     Makeup                       Face
# 12                  Fragrance                      Women
# 13                    Dresses           Above Knee, Mini
# 14            Office supplies            School Supplies
# 15                      Shoes                      Boots
# 16                     Makeup                Makeup Sets
# 17                     Makeup                       Eyes
# 18                       Gear       Backpacks & Carriers
# 19                     Makeup            Makeup Palettes
# 20             Tops & Blouses                     Blouse
# 21             Tops & Blouses                 Tank, Cami
# 22           Athletic Apparel                Sports Bras
# 23  Cell Phones & Accessories  Cell Phones & Smartphones
# 24  Cell Phones & Accessories         Chargers & Cradles
# 25             Tops & Blouses                   T-Shirts
# 26                      Shoes                   Athletic
# 27  Cell Phones & Accessories      Cases, Covers & Skins
# 28           Athletic Apparel    Pants, Tights, Leggings
# 29                   Swimwear                  One-Piece
# 30                      Jeans                   Boot Cut
# 31                     Makeup                       Eyes
# 32           Athletic Apparel    Pants, Tights, Leggings
# 33                  Underwear                       Bras
# 34                  Skin Care                       Face
# 35                       Toys    Stuffed Animals & Plush
# 36           Athletic Apparel    Pants, Tights, Leggings
# 37           Women's Handbags           Totes & Shoppers
# 38           Athletic Apparel              Shirts & Tops
# 39     Video Games & Consoles                   Consoles
# 40                  Underwear                       Bras
# 41                     Makeup                Makeup Sets
# 42                  Underwear                       Bras
# 43                  Skin Care                       Face
# 44                     Makeup                       Face
# 45               Collectibles                      Glass
# 46            Coats & Jackets                       Vest
# 47                       Toys              Arts & Crafts
# 48             Tops & Blouses                     Blouse
# 49                      Pants            Capris, Cropped
# 50                     Makeup                       Eyes

# %%
X_clean.head()
# Out:
# 0                              name item_condition_id brand_name shipping  \
# 1    mlb cincinnati reds shirt size                 3                   1
# 2  razer blackwidow chroma keyboard                 3      Razer        0
# 3                    ava viv blouse                 1     Target        1
# 4             leather horse statues                 1                   1
# 5                  gold plated rose                 1                   0
#
# 0                                   item_description    category1  \
# 1                                 No description yet          Men
# 2  This keyboard is in great condition and works ...  Electronics
# 3  Adorable top with a hint of lace and a key hol...        Women
# 4  New with tags. Leather horses. Retail for [rm]...         Home
# 5          Complete with certificate of authenticity        Women
#
# 0            category2           category3
# 1                 Tops            T-shirts
# 2  Computers & Tablets  Components & Parts
# 3       Tops & Blouses              Blouse
# 4           Home Décor  Home Décor Accents
# 5              Jewelry           Necklaces

# %%
# Only include features I have been working on (temporary)
X_train = X_clean[:]
del X_train['item_condition_id']
del X_train['brand_name']
del X_train['shipping']
del X_train['item_description']

X_train.head()
# Out:
# 0                              name    category1            category2  \
# 1    mlb cincinnati reds shirt size          Men                 Tops
# 2  razer blackwidow chroma keyboard  Electronics  Computers & Tablets
# 3                    ava viv blouse        Women       Tops & Blouses
# 4             leather horse statues         Home           Home Décor
# 5                  gold plated rose        Women              Jewelry
#
# 0           category3
# 1            T-shirts
# 2  Components & Parts
# 3              Blouse
# 4  Home Décor Accents
# 5           Necklaces

# %% [markdown]
# ### Vectorise words

# %%
# Vectorise words
print('Vectorising words...')
start_time = time.time()

vectorizer = CountVectorizer(analyzer='word', lowercase=True)

name_features = vectorizer.fit_transform(X_train.loc[:, 'name'])
cat1_features = vectorizer.fit_transform(X_train.loc[:, 'category1'])
cat2_features = vectorizer.fit_transform(X_train.loc[:, 'category2'])
cat3_features = vectorizer.fit_transform(X_train.loc[:, 'category3'])

# For testing
features = vectorizer.fit_transform(X_clean.loc[:, 'item_description'])

#df_train = pd.DataFrame(vectorizer.transform(X_train).todense(), columns=vectorizer.get_feature_names())
#vectorizer = CountVectorizer(analyzer='word', lowercase=True)

#X_clean.loc[:, 'name'] = vectorizer.fit_transform(X_clean.loc[:, 'name'])
#X_clean.loc[:, 'category_name'] = vectorizer.fit_transform(X_clean.loc[:, 'category_name'])
#X_clean.loc[:, 'item_description'] = vectorizer.fit_transform(X_clean.loc[:, 'item_description'])

print(f'Done. Time taken: {time.time() - start_time:.2f}s')
# Out:
# Vectorising words...
# Done. Time taken: 0.18s

# %% [markdown]
# ### ML algorithm

# %%
# Simple linear regression for testing
start_time = time.time()

# Fit model
print('Fitting model (Linear Regression)...')
model_lr = LinearRegression()
model_lr.fit(features, y[:n])

print(f'Done. Time taken: {time.time() - start_time:.2f}s\n')

# Predictions for train and test data
y_preds = model_lr.predict(features)
# Out:
# Fitting model (Linear Regression)...
# Done. Time taken: 8.38s

# %% [markdown]
# ### Cost function

# %% [markdown]
# Evaluation metric is Root Mean Squared Logarithmic Error (RMSLE).

# %%
# Mean Squared Error (MSE)
RMSE = np.sqrt(sum((y_preds - y[:n])**2) / n)
print(RMSE)

# Room Mean Squared Logarithmic Error (RMSLE)
#RMSLE = np.sqrt(sum((np.log(y_preds + 1) - np.log(y[:n] + 1))**2) / n)
#print(RMSLE)
# Out:
# 23.857362674848975

# %%
print(max(y))
print(min(y))
print(np.mean(y))
print(np.std(y))
# Out:
# 2009.0
# 0.0
# 26.737516146330442
# 38.586053299794486
